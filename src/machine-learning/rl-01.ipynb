# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def V(p):
    q = 1-p
    a = p - p*p/(1-q*q)
    b = -p*(2-p)/(1-q*q)-1
    return b/a

# %%
x = np.linspace(0.01,0.99, 100)
v = [V(xi) for xi in x]
plt.plot(x,v)
plt.ylim([-100, -11.6])
# Out:
# (-100, -11.6)
